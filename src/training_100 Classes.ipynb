# %%
import os
import json
import math
import random
from typing import List

import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence, pack_padded_sequence, pad_packed_sequence
from sklearn.utils.class_weight import compute_class_weight
from tqdm import tqdm
import matplotlib.pyplot as plt
import cv2

# %% [markdown]
# # 1. HYPERPARAMETERS & CONFIGURATION

# %% [markdown]
# ## --- Data Paths ---

# %%
LANDMARK_FILE = '/kaggle/input/landmarks-553-for-300-classes/Landmarks_300_553_3D.npz'
SPLIT_FILE = '/kaggle/input/wlasl2000-resized/wlasl-complete/nslt_100.json'

# %% [markdown]
# ## --- Reproducibility ---

# %%
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
if torch.cuda.is_available():
    torch.cuda.manual_seed_all(SEED)

# %% [markdown]
# ## --- Model Hyperparameters ---

# %%
INPUT_SIZE = 553 * 3
NUM_CLASSES = 100
LSTM_HIDDEN_SIZE = 256
LSTM_NUM_LAYERS = 2
MODEL_DROPOUT = 0.5

# %% [markdown]
# ## --- Training Hyperparameters ---

# %%
EPOCHS = 200
BATCH_SIZE = 32
BASE_LR = 3e-4
GRADIENT_CLIP_NORM = 1.0
WEIGHT_DECAY = 1e-4
LABEL_SMOOTHING = 0.1
MIXUP_ALPHA = 0.4
WARMUP_EPOCHS = max(5, int(0.1 * EPOCHS))

# %% [markdown]
# ## --- System Configuration ---

# %%
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
USE_AMP = DEVICE.type == 'cuda'
print(f"Using device: {DEVICE}, AMP: {USE_AMP}")
# Out:
# Using device: cuda, AMP: True

# %% [markdown]
# # 2. PREPROCESSOR, DATASET, AND MODEL CLASSES

# %%
class LandmarkPreprocessor:
    def __init__(self, augment=True):
        self.augment = augment
        self.POSE_IDXS = list(range(0, 33)); self.FACE_IDXS = list(range(33, 501)); self.LEFT_HAND_IDXS = list(range(511, 532)); self.RIGHT_HAND_IDXS = list(range(532, 552))
    def normalize_frame(self, frame_landmarks: np.ndarray) -> np.ndarray:
        normalized_frame = np.copy(frame_landmarks); pose_landmarks = frame_landmarks[self.POSE_IDXS]
        if np.sum(np.abs(pose_landmarks)) > 0:
            nose, l_s, r_s, l_e = pose_landmarks[0, :2], pose_landmarks[11, :2], pose_landmarks[12, :2], pose_landmarks[2, :2]; dist = np.linalg.norm(l_s - r_s)
            if dist > 1e-4:
                hu = dist / 2.0; bw, bh, bx, by = 6 * hu, 7 * hu, nose[0] - 3 * hu, l_e[1] - 0.5 * hu; pf_idxs = self.POSE_IDXS + self.FACE_IDXS
                if bw > 0 and bh > 0:
                    normalized_frame[pf_idxs, 0] = (frame_landmarks[pf_idxs, 0] - bx) / bw - 0.5; normalized_frame[pf_idxs, 1] = (frame_landmarks[pf_idxs, 1] - by) / bh - 0.5
        for h_idxs in [self.LEFT_HAND_IDXS, self.RIGHT_HAND_IDXS]:
            hand_landmarks = frame_landmarks[h_idxs]
            if np.sum(np.abs(hand_landmarks)) > 0:
                xs, ys = hand_landmarks[:, 0], hand_landmarks[:, 1]
                if len(xs) > 0 and np.max(xs) != np.min(xs):
                    xmin, xmax, ymin, ymax = np.min(xs), np.max(xs), np.min(ys), np.max(ys); box_size = max(xmax - xmin, ymax - ymin, 1e-4)
                    normalized_frame[h_idxs, 0] = (hand_landmarks[:, 0] - xmin) / box_size - 0.5; normalized_frame[h_idxs, 1] = (hand_landmarks[:, 1] - ymin) / box_size - 0.5
        return normalized_frame
    def augment_sequence(self, sequence: np.ndarray) -> np.ndarray:
        angle = random.uniform(-13, 13); rad = np.deg2rad(angle); cos, sin = np.cos(rad), np.sin(rad); rot_matrix = np.array([[cos, -sin], [sin, cos]])
        points = sequence[:, :, :2].reshape(-1, 2); rotated_points = points @ rot_matrix.T; sequence[:, :, :2] = rotated_points.reshape(sequence.shape[0], -1, 2)
        noise = np.random.normal(0, 0.005, sequence.shape).astype(np.float32); sequence += noise
        return sequence
    def __call__(self, landmark_sequence: np.ndarray, is_train: bool):
        landmark_sequence[np.isnan(landmark_sequence)] = 0; normalized_sequence = np.array([self.normalize_frame(frame) for frame in landmark_sequence])
        if is_train and self.augment: normalized_sequence = self.augment_sequence(normalized_sequence)
        return normalized_sequence

# %% [markdown]
# ## Dataset Class

# %%
class WLASLLandmarkDataset(Dataset):
    def __init__(self, landmark_path, split_file_path, split='train'):
        self.split = split; self.preprocessor = LandmarkPreprocessor()
        landmarks_data = dict(np.load(landmark_path, allow_pickle=True))
        with open(split_file_path, 'r') as f: split_data = json.load(f)
        split_dict = split_data.get('root', split_data)
        self.samples = []
        for video_id, info in split_dict.items():
            if info.get('subset') == self.split:
                if video_id in landmarks_data:
                    self.samples.append({"landmarks": landmarks_data[video_id], "label": int(info['action'][0])})
        print(f"✅ Created '{self.split}' split with {len(self.samples)} samples.")
    def __len__(self): return len(self.samples)
    def __getitem__(self, idx):
        sample = self.samples[idx]; landmark_sequence, class_index = sample["landmarks"], sample["label"]
        processed_sequence = self.preprocessor(landmark_sequence, is_train=(self.split == 'train'))
        flattened_landmarks = processed_sequence.reshape(processed_sequence.shape[0], -1)
        return torch.tensor(flattened_landmarks, dtype=torch.float32), torch.tensor(class_index, dtype=torch.long)

def variable_length_collate_fn(batch):
    sequences, labels = zip(*batch); lengths = torch.tensor([len(seq) for seq in sequences], dtype=torch.long)
    padded_sequences = pad_sequence(sequences, batch_first=True, padding_value=0.0)
    return padded_sequences, torch.tensor(labels, dtype=torch.long), lengths

# %% [markdown]
# ## Model Architecture

# %%
class Attention(nn.Module):
    def __init__(self, hidden_size):
        super(Attention, self).__init__(); self.attn_net = nn.Sequential(nn.Linear(hidden_size, hidden_size // 2), nn.Tanh(), nn.Linear(hidden_size // 2, 1))
    def forward(self, lstm_output):
        attn_scores = self.attn_net(lstm_output).squeeze(-1); attn_weights = F.softmax(attn_scores, dim=1).unsqueeze(1)
        context_vector = torch.bmm(attn_weights, lstm_output).squeeze(1); return context_vector, attn_weights

class LandmarkBiLSTMAttentionModel(nn.Module):
    def __init__(self, input_size, num_classes, hidden_size, num_layers, dropout_rate):
        super(LandmarkBiLSTMAttentionModel, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bidirectional=True, dropout=0.2 if num_layers > 1 else 0)
        self.attention = Attention(hidden_size * 2)
        self.layer_norm = nn.LayerNorm(hidden_size * 2)
        self.dropout = nn.Dropout(dropout_rate)
        self.fc = nn.Linear(hidden_size * 2, num_classes)
    def forward(self, x, lengths):
        packed_input = pack_padded_sequence(x, lengths.cpu(), batch_first=True, enforce_sorted=False)
        packed_output, (h_n, _) = self.lstm(packed_input)
        lstm_output, _ = pad_packed_sequence(packed_output, batch_first=True)
        context_vector, _ = self.attention(lstm_output)
        x = self.layer_norm(context_vector)
        return self.fc(self.dropout(x))

# %% [markdown]
# # 3. TRAINING EXECUTION

# %% [markdown]
# ## --- Data Loading ---

# %%
print("\n--- Initializing DataLoaders ---")
train_dataset = WLASLLandmarkDataset(LANDMARK_FILE, SPLIT_FILE, split='train')
val_dataset = WLASLLandmarkDataset(LANDMARK_FILE, SPLIT_FILE, split='val')
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=variable_length_collate_fn, num_workers=4, pin_memory=True)
val_loader = DataLoader(val_dataset, batch_size=BATCH_SIZE, shuffle=False, collate_fn=variable_length_collate_fn, num_workers=4, pin_memory=True)
# Out:
# --- Initializing DataLoaders ---
# ✅ Created 'train' split with 1442 samples.
# ✅ Created 'val' split with 338 samples.

# %% [markdown]
# ## --- Class Weights ---

# %%
train_labels = [int(sample['label']) for sample in train_dataset.samples]
class_weights = compute_class_weight('balanced', classes=np.arange(NUM_CLASSES), y=train_labels)
class_weights_tensor = torch.tensor(class_weights, dtype=torch.float32).to(DEVICE)
print("Class weights calculated.")
# Out:
# Class weights calculated.

# %% [markdown]
# ## --- Model, Optimizer, Scheduler, Scaler ---

# %%
print("\n--- Initializing Model ---")
model = LandmarkBiLSTMAttentionModel(INPUT_SIZE, NUM_CLASSES, LSTM_HIDDEN_SIZE, LSTM_NUM_LAYERS, MODEL_DROPOUT).to(DEVICE)
optimizer = torch.optim.AdamW(model.parameters(), lr=BASE_LR, weight_decay=WEIGHT_DECAY)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=5, verbose=True)
scaler = torch.cuda.amp.GradScaler(enabled=USE_AMP)
# Out:
# --- Initializing Model ---
# /usr/local/lib/python3.11/dist-packages/torch/optim/lr_scheduler.py:62: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn(
# /tmp/ipykernel_36/3019509604.py:5: FutureWarning: `torch.cuda.amp.GradScaler(args...)` is deprecated. Please use `torch.amp.GradScaler('cuda', args...)` instead.
#   scaler = torch.cuda.amp.GradScaler(enabled=USE_AMP)

# %% [markdown]
# # --- Training Loop ---

# %%
train_loss_history, train_acc_history, val_loss_history, val_acc_history = [], [], [], []
best_accuracy = 0.0

# %%
print("\n--- Starting Training ---")
for epoch in range(EPOCHS):
    if epoch < WARMUP_EPOCHS:
        tiny_lr = BASE_LR * 0.01; current_lr = tiny_lr + (BASE_LR - tiny_lr) * ((epoch + 1) / WARMUP_EPOCHS)
        dropout_p, label_smoothing, current_weight_decay = 0.1, 0.0, 1e-6
    else:
        current_lr, dropout_p, label_smoothing, current_weight_decay = BASE_LR, MODEL_DROPOUT, LABEL_SMOOTHING, WEIGHT_DECAY
    for pg in optimizer.param_groups: pg['lr'], pg['weight_decay'] = current_lr, current_weight_decay
    model.dropout.p = dropout_p
    criterion = nn.CrossEntropyLoss(weight=class_weights_tensor, label_smoothing=label_smoothing)

    model.train(); running_loss, train_correct, train_total = 0.0, 0.0, 0
    for landmarks, labels, lengths in train_loader:
        landmarks, labels, lengths = landmarks.to(DEVICE), labels.to(DEVICE), lengths.to(DEVICE)
        batch_size = landmarks.size(0)
        if batch_size > 1 and MIXUP_ALPHA > 0:
            lam = np.random.beta(MIXUP_ALPHA, MIXUP_ALPHA)
            shuffle_indices = torch.randperm(batch_size, device=DEVICE)
            shuffled_landmarks, shuffled_labels = landmarks[shuffle_indices], labels[shuffle_indices]
            mixed_landmarks = lam * landmarks + (1 - lam) * shuffled_landmarks
        else:
            lam, mixed_landmarks, shuffled_labels = 1.0, landmarks, labels
        optimizer.zero_grad()
        with torch.cuda.amp.autocast(enabled=USE_AMP):
            outputs = model(mixed_landmarks, lengths)
            loss = lam * criterion(outputs, labels) + (1 - lam) * criterion(outputs, shuffled_labels)
        scaler.scale(loss).backward()
        scaler.unscale_(optimizer); torch.nn.utils.clip_grad_norm_(model.parameters(), max_norm=GRADIENT_CLIP_NORM)
        scaler.step(optimizer); scaler.update()
        running_loss += loss.item() * float(batch_size); _, predicted = torch.max(outputs.detach(), 1)
        train_total += labels.size(0); train_correct += (lam * (predicted == labels).sum().item() + (1 - lam) * (predicted == shuffled_labels).sum().item())
    avg_train_loss, train_accuracy = running_loss / train_total, 100.0 * train_correct / train_total

    model.eval(); val_loss, val_correct, val_total = 0.0, 0, 0
    with torch.no_grad():
        for landmarks, labels, lengths in val_loader:
            landmarks, labels, lengths = landmarks.to(DEVICE), labels.to(DEVICE), lengths.to(DEVICE)
            with torch.cuda.amp.autocast(enabled=USE_AMP):
                outputs = model(landmarks, lengths); loss = criterion(outputs, labels)
            val_loss += loss.item() * labels.size(0); _, predicted = torch.max(outputs, 1)
            val_total += labels.size(0); val_correct += (predicted == labels).sum().item()
    avg_val_loss, val_accuracy = val_loss / max(1, val_total), 100.0 * val_correct / max(1, val_total)
    
    scheduler.step(avg_val_loss)
    train_loss_history.append(avg_train_loss); train_acc_history.append(train_accuracy); val_loss_history.append(avg_val_loss); val_acc_history.append(val_accuracy)
    
    print(f"Epoch {epoch+1}/{EPOCHS} | lr={current_lr:.6g} | Train Loss={avg_train_loss:.4f}, Train Acc={train_accuracy:.2f}% | Val Loss={avg_val_loss:.4f}, Val Acc={val_accuracy:.2f}%")
    
    if val_accuracy > best_accuracy:
        best_accuracy = val_accuracy
        torch.save(model.state_dict(), 'best_landmark_attention_model_100.pth'); print(f"✅ New best model saved: {best_accuracy:.2f}%")

print("\n✨ Training finished!")
# Out:
# --- Starting Training ---
# /tmp/ipykernel_36/2356008643.py:24: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=USE_AMP):
# /tmp/ipykernel_36/2356008643.py:38: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(enabled=USE_AMP):
# Epoch 1/200 | lr=1.785e-05 | Train Loss=4.7426, Train Acc=0.59% | Val Loss=4.6343, Val Acc=1.18%
# ✅ New best model saved: 1.18%
# Epoch 2/200 | lr=3.27e-05 | Train Loss=4.6616, Train Acc=1.19% | Val Loss=4.5765, Val Acc=1.78%
# ✅ New best model saved: 1.78%
# Epoch 3/200 | lr=4.755e-05 | Train Loss=4.6262, Train Acc=1.08% | Val Loss=4.5396, Val Acc=4.14%
# ✅ New best model saved: 4.14%
# Epoch 4/200 | lr=6.24e-05 | Train Loss=4.5622, Train Acc=2.17% | Val Loss=4.3909, Val Acc=4.73%
# ✅ New best model saved: 4.73%
# Epoch 5/200 | lr=7.725e-05 | Train Loss=4.3422, Train Acc=4.71% | Val Loss=4.0431, Val Acc=8.58%
# ✅ New best model saved: 8.58%
# Epoch 6/200 | lr=9.21e-05 | Train Loss=4.0170, Train Acc=9.75% | Val Loss=3.6910, Val Acc=15.09%
# ✅ New best model saved: 15.09%
# Epoch 7/200 | lr=0.00010695 | Train Loss=3.7153, Train Acc=16.38% | Val Loss=3.4437, Val Acc=19.82%
# ✅ New best model saved: 19.82%
# Epoch 8/200 | lr=0.0001218 | Train Loss=3.5530, Train Acc=17.75% | Val Loss=3.1801, Val Acc=26.92%
# ✅ New best model saved: 26.92%
# Epoch 9/200 | lr=0.00013665 | Train Loss=3.2289, Train Acc=27.07% | Val Loss=3.0205, Val Acc=31.36%
# ✅ New best model saved: 31.36%
# Epoch 10/200 | lr=0.0001515 | Train Loss=3.1595, Train Acc=28.70% | Val Loss=2.7832, Val Acc=37.28%
# ✅ New best model saved: 37.28%
# Epoch 11/200 | lr=0.00016635 | Train Loss=2.9190, Train Acc=33.92% | Val Loss=2.6139, Val Acc=40.83%
# ✅ New best model saved: 40.83%
# Epoch 12/200 | lr=0.0001812 | Train Loss=2.7800, Train Acc=38.06% | Val Loss=2.5947, Val Acc=42.31%
# ✅ New best model saved: 42.31%
# Epoch 13/200 | lr=0.00019605 | Train Loss=2.8182, Train Acc=35.94% | Val Loss=2.3422, Val Acc=46.75%
# ✅ New best model saved: 46.75%
# Epoch 14/200 | lr=0.0002109 | Train Loss=2.6656, Train Acc=38.64% | Val Loss=2.2038, Val Acc=50.89%
# ✅ New best model saved: 50.89%
# Epoch 15/200 | lr=0.00022575 | Train Loss=2.5280, Train Acc=44.43% | Val Loss=2.3531, Val Acc=43.49%
# Epoch 16/200 | lr=0.0002406 | Train Loss=2.3785, Train Acc=46.18% | Val Loss=2.0294, Val Acc=50.59%
# Epoch 17/200 | lr=0.00025545 | Train Loss=2.4156, Train Acc=46.15% | Val Loss=1.9316, Val Acc=53.55%
# ✅ New best model saved: 53.55%
# Epoch 18/200 | lr=0.0002703 | Train Loss=2.2776, Train Acc=49.66% | Val Loss=1.9218, Val Acc=56.51%
# ✅ New best model saved: 56.51%
# Epoch 19/200 | lr=0.00028515 | Train Loss=2.1658, Train Acc=52.44% | Val Loss=1.9597, Val Acc=49.41%
# Epoch 20/200 | lr=0.0003 | Train Loss=2.1182, Train Acc=54.13% | Val Loss=1.7455, Val Acc=56.80%
# ✅ New best model saved: 56.80%
# Epoch 21/200 | lr=0.0003 | Train Loss=2.6990, Train Acc=48.42% | Val Loss=2.3342, Val Acc=54.44%
# Epoch 22/200 | lr=0.0003 | Train Loss=2.5271, Train Acc=54.62% | Val Loss=2.2349, Val Acc=60.36%
# ✅ New best model saved: 60.36%
# Epoch 23/200 | lr=0.0003 | Train Loss=2.6456, Train Acc=52.21% | Val Loss=2.2778, Val Acc=53.85%
# Epoch 24/200 | lr=0.0003 | Train Loss=2.5139, Train Acc=53.14% | Val Loss=2.1446, Val Acc=60.95%
# ✅ New best model saved: 60.95%
# Epoch 25/200 | lr=0.0003 | Train Loss=2.5167, Train Acc=54.93% | Val Loss=2.1838, Val Acc=58.58%
# Epoch 26/200 | lr=0.0003 | Train Loss=2.4019, Train Acc=59.34% | Val Loss=2.0008, Val Acc=65.68%
# ✅ New best model saved: 65.68%
# Epoch 27/200 | lr=0.0003 | Train Loss=2.3684, Train Acc=59.60% | Val Loss=2.0574, Val Acc=63.02%
# Epoch 28/200 | lr=0.0003 | Train Loss=2.4256, Train Acc=56.92% | Val Loss=2.0591, Val Acc=61.54%
# Epoch 29/200 | lr=0.0003 | Train Loss=2.3648, Train Acc=59.71% | Val Loss=1.9979, Val Acc=66.27%
# ✅ New best model saved: 66.27%
# Epoch 30/200 | lr=0.0003 | Train Loss=2.5044, Train Acc=54.95% | Val Loss=1.9796, Val Acc=67.16%
# ✅ New best model saved: 67.16%
# Epoch 31/200 | lr=0.0003 | Train Loss=2.3638, Train Acc=61.11% | Val Loss=1.9474, Val Acc=66.27%
# Epoch 32/200 | lr=0.0003 | Train Loss=2.3196, Train Acc=61.24% | Val Loss=1.8913, Val Acc=68.05%
# ✅ New best model saved: 68.05%
# Epoch 33/200 | lr=0.0003 | Train Loss=2.3719, Train Acc=61.13% | Val Loss=1.9297, Val Acc=68.93%
# ✅ New best model saved: 68.93%
# Epoch 34/200 | lr=0.0003 | Train Loss=2.2326, Train Acc=64.66% | Val Loss=1.9169, Val Acc=68.64%
# Epoch 35/200 | lr=0.0003 | Train Loss=2.3276, Train Acc=63.19% | Val Loss=1.8429, Val Acc=72.19%
# ✅ New best model saved: 72.19%
# Epoch 36/200 | lr=0.0003 | Train Loss=2.1278, Train Acc=68.65% | Val Loss=1.9563, Val Acc=67.16%
# Epoch 37/200 | lr=0.0003 | Train Loss=2.1708, Train Acc=65.96% | Val Loss=1.9810, Val Acc=65.38%
# Epoch 38/200 | lr=0.0003 | Train Loss=2.2816, Train Acc=62.94% | Val Loss=1.8781, Val Acc=68.93%
# Epoch 39/200 | lr=0.0003 | Train Loss=2.2370, Train Acc=65.04% | Val Loss=1.8457, Val Acc=68.34%
# Epoch 40/200 | lr=0.0003 | Train Loss=2.2582, Train Acc=64.40% | Val Loss=1.8957, Val Acc=68.93%
# Epoch 41/200 | lr=0.0003 | Train Loss=2.2618, Train Acc=64.56% | Val Loss=1.8227, Val Acc=69.82%
# Epoch 42/200 | lr=0.0003 | Train Loss=2.4163, Train Acc=60.45% | Val Loss=1.8678, Val Acc=67.75%
# Epoch 43/200 | lr=0.0003 | Train Loss=2.0529, Train Acc=71.00% | Val Loss=1.8161, Val Acc=71.60%
# Epoch 44/200 | lr=0.0003 | Train Loss=2.1143, Train Acc=68.84% | Val Loss=1.8314, Val Acc=69.23%
# Epoch 45/200 | lr=0.0003 | Train Loss=1.9754, Train Acc=73.21% | Val Loss=1.8871, Val Acc=66.27%
# Epoch 46/200 | lr=0.0003 | Train Loss=2.1118, Train Acc=70.42% | Val Loss=1.7900, Val Acc=70.71%
# Epoch 47/200 | lr=0.0003 | Train Loss=2.1683, Train Acc=68.97% | Val Loss=1.7558, Val Acc=74.56%
# ✅ New best model saved: 74.56%
# Epoch 48/200 | lr=0.0003 | Train Loss=2.0042, Train Acc=72.87% | Val Loss=1.8534, Val Acc=67.75%
# Epoch 49/200 | lr=0.0003 | Train Loss=2.0884, Train Acc=70.93% | Val Loss=1.7619, Val Acc=72.19%
# Epoch 50/200 | lr=0.0003 | Train Loss=2.0860, Train Acc=71.87% | Val Loss=1.8251, Val Acc=70.12%
# Epoch 51/200 | lr=0.0003 | Train Loss=1.9530, Train Acc=74.85% | Val Loss=1.8578, Val Acc=71.89%
# Epoch 52/200 | lr=0.0003 | Train Loss=2.2064, Train Acc=66.06% | Val Loss=1.8348, Val Acc=70.12%
# Epoch 53/200 | lr=0.0003 | Train Loss=1.9298, Train Acc=75.38% | Val Loss=1.7377, Val Acc=74.85%
# ✅ New best model saved: 74.85%
# Epoch 54/200 | lr=0.0003 | Train Loss=1.8952, Train Acc=75.73% | Val Loss=1.7742, Val Acc=72.49%
# Epoch 55/200 | lr=0.0003 | Train Loss=2.0077, Train Acc=72.63% | Val Loss=1.7405, Val Acc=73.37%
# Epoch 56/200 | lr=0.0003 | Train Loss=1.8779, Train Acc=76.57% | Val Loss=1.7399, Val Acc=73.96%
# Epoch 57/200 | lr=0.0003 | Train Loss=1.9585, Train Acc=73.66% | Val Loss=1.6949, Val Acc=74.85%
# Epoch 58/200 | lr=0.0003 | Train Loss=1.9833, Train Acc=73.42% | Val Loss=1.7857, Val Acc=71.89%
# Epoch 59/200 | lr=0.0003 | Train Loss=2.1142, Train Acc=69.43% | Val Loss=1.7484, Val Acc=72.19%
# Epoch 60/200 | lr=0.0003 | Train Loss=1.6885, Train Acc=80.81% | Val Loss=1.7336, Val Acc=73.37%
# Epoch 61/200 | lr=0.0003 | Train Loss=1.9458, Train Acc=74.00% | Val Loss=1.7689, Val Acc=73.37%
# Epoch 62/200 | lr=0.0003 | Train Loss=1.9785, Train Acc=75.65% | Val Loss=1.7192, Val Acc=74.26%
# Epoch 63/200 | lr=0.0003 | Train Loss=1.8950, Train Acc=76.53% | Val Loss=1.6792, Val Acc=75.44%
# ✅ New best model saved: 75.44%
# Epoch 64/200 | lr=0.0003 | Train Loss=1.9587, Train Acc=75.51% | Val Loss=1.7580, Val Acc=73.67%
# Epoch 65/200 | lr=0.0003 | Train Loss=1.9824, Train Acc=73.74% | Val Loss=1.7345, Val Acc=75.44%
# Epoch 66/200 | lr=0.0003 | Train Loss=1.9145, Train Acc=75.26% | Val Loss=1.6878, Val Acc=75.15%
# Epoch 67/200 | lr=0.0003 | Train Loss=1.8605, Train Acc=78.27% | Val Loss=1.6746, Val Acc=77.51%
# ✅ New best model saved: 77.51%
# Epoch 68/200 | lr=0.0003 | Train Loss=1.8907, Train Acc=76.85% | Val Loss=1.6591, Val Acc=74.85%
# Epoch 69/200 | lr=0.0003 | Train Loss=2.0815, Train Acc=70.89% | Val Loss=1.7094, Val Acc=75.44%
# Epoch 70/200 | lr=0.0003 | Train Loss=2.0394, Train Acc=72.60% | Val Loss=1.6974, Val Acc=75.15%
# Epoch 71/200 | lr=0.0003 | Train Loss=2.1065, Train Acc=71.59% | Val Loss=1.7188, Val Acc=74.85%
# Epoch 72/200 | lr=0.0003 | Train Loss=1.6756, Train Acc=80.89% | Val Loss=1.6515, Val Acc=76.33%
# Epoch 73/200 | lr=0.0003 | Train Loss=1.8760, Train Acc=77.33% | Val Loss=1.6723, Val Acc=74.26%
# Epoch 74/200 | lr=0.0003 | Train Loss=1.8287, Train Acc=77.39% | Val Loss=1.6774, Val Acc=76.92%
# Epoch 75/200 | lr=0.0003 | Train Loss=2.0317, Train Acc=72.99% | Val Loss=1.6908, Val Acc=76.63%
# Epoch 76/200 | lr=0.0003 | Train Loss=1.7794, Train Acc=80.33% | Val Loss=1.7238, Val Acc=75.15%
# Epoch 77/200 | lr=0.0003 | Train Loss=1.8385, Train Acc=77.33% | Val Loss=1.6192, Val Acc=77.22%
# Epoch 78/200 | lr=0.0003 | Train Loss=1.9734, Train Acc=76.26% | Val Loss=1.7205, Val Acc=77.51%
# Epoch 79/200 | lr=0.0003 | Train Loss=1.7790, Train Acc=78.94% | Val Loss=1.6430, Val Acc=77.22%
# Epoch 80/200 | lr=0.0003 | Train Loss=1.8834, Train Acc=75.62% | Val Loss=1.6967, Val Acc=76.92%
# Epoch 81/200 | lr=0.0003 | Train Loss=1.9671, Train Acc=74.26% | Val Loss=1.8049, Val Acc=72.49%
# Epoch 82/200 | lr=0.0003 | Train Loss=1.9065, Train Acc=76.18% | Val Loss=1.7204, Val Acc=76.04%
# Epoch 83/200 | lr=0.0003 | Train Loss=1.8133, Train Acc=78.78% | Val Loss=1.6631, Val Acc=77.22%
# Epoch 84/200 | lr=0.0003 | Train Loss=2.0354, Train Acc=72.37% | Val Loss=1.6332, Val Acc=77.81%
# ✅ New best model saved: 77.81%
# Epoch 85/200 | lr=0.0003 | Train Loss=1.9637, Train Acc=75.98% | Val Loss=1.7234, Val Acc=73.67%
# Epoch 86/200 | lr=0.0003 | Train Loss=1.9344, Train Acc=74.76% | Val Loss=1.6909, Val Acc=78.11%
# ✅ New best model saved: 78.11%
# Epoch 87/200 | lr=0.0003 | Train Loss=1.9410, Train Acc=75.38% | Val Loss=1.7030, Val Acc=76.92%
# Epoch 88/200 | lr=0.0003 | Train Loss=1.7735, Train Acc=80.29% | Val Loss=1.7079, Val Acc=77.22%
# Epoch 89/200 | lr=0.0003 | Train Loss=2.0349, Train Acc=71.35% | Val Loss=1.6676, Val Acc=76.63%
# Epoch 90/200 | lr=0.0003 | Train Loss=1.8767, Train Acc=77.71% | Val Loss=1.6510, Val Acc=78.70%
# ✅ New best model saved: 78.70%
# Epoch 91/200 | lr=0.0003 | Train Loss=1.9655, Train Acc=74.69% | Val Loss=1.7083, Val Acc=75.15%
# Epoch 92/200 | lr=0.0003 | Train Loss=1.8362, Train Acc=77.59% | Val Loss=1.6752, Val Acc=77.22%
# Epoch 93/200 | lr=0.0003 | Train Loss=1.8154, Train Acc=78.08% | Val Loss=1.7680, Val Acc=74.85%
# Epoch 94/200 | lr=0.0003 | Train Loss=1.7736, Train Acc=79.67% | Val Loss=1.6942, Val Acc=73.37%
# Epoch 95/200 | lr=0.0003 | Train Loss=2.0874, Train Acc=71.44% | Val Loss=1.6967, Val Acc=75.44%
# Epoch 96/200 | lr=0.0003 | Train Loss=1.8170, Train Acc=78.34% | Val Loss=1.7167, Val Acc=74.85%
# Epoch 97/200 | lr=0.0003 | Train Loss=1.9073, Train Acc=75.50% | Val Loss=1.6718, Val Acc=75.44%
# Epoch 98/200 | lr=0.0003 | Train Loss=2.0132, Train Acc=74.00% | Val Loss=1.7258, Val Acc=75.44%
# Epoch 99/200 | lr=0.0003 | Train Loss=2.0651, Train Acc=71.73% | Val Loss=1.6772, Val Acc=76.92%
# Epoch 100/200 | lr=0.0003 | Train Loss=1.7847, Train Acc=79.90% | Val Loss=1.6827, Val Acc=75.15%
# Epoch 101/200 | lr=0.0003 | Train Loss=1.7772, Train Acc=80.44% | Val Loss=1.6802, Val Acc=75.15%
# Epoch 102/200 | lr=0.0003 | Train Loss=1.7470, Train Acc=79.70% | Val Loss=1.7329, Val Acc=76.04%
# Epoch 103/200 | lr=0.0003 | Train Loss=1.8200, Train Acc=79.47% | Val Loss=1.6635, Val Acc=76.33%
# Epoch 104/200 | lr=0.0003 | Train Loss=1.7348, Train Acc=82.20% | Val Loss=1.6869, Val Acc=76.63%
# Epoch 105/200 | lr=0.0003 | Train Loss=1.8081, Train Acc=78.83% | Val Loss=1.7195, Val Acc=73.96%
# Epoch 106/200 | lr=0.0003 | Train Loss=1.6453, Train Acc=83.83% | Val Loss=1.6501, Val Acc=77.81%
# Epoch 107/200 | lr=0.0003 | Train Loss=1.7855, Train Acc=80.44% | Val Loss=1.6746, Val Acc=76.63%
# Epoch 108/200 | lr=0.0003 | Train Loss=1.7980, Train Acc=77.66% | Val Loss=1.6532, Val Acc=77.81%
# Epoch 109/200 | lr=0.0003 | Train Loss=1.8985, Train Acc=76.95% | Val Loss=1.6927, Val Acc=76.92%
# Epoch 110/200 | lr=0.0003 | Train Loss=1.7996, Train Acc=79.49% | Val Loss=1.7047, Val Acc=74.56%
# Epoch 111/200 | lr=0.0003 | Train Loss=1.6406, Train Acc=83.50% | Val Loss=1.6949, Val Acc=76.63%
# Epoch 112/200 | lr=0.0003 | Train Loss=1.7323, Train Acc=82.42% | Val Loss=1.6720, Val Acc=76.33%
# Epoch 113/200 | lr=0.0003 | Train Loss=1.8427, Train Acc=77.97% | Val Loss=1.7001, Val Acc=75.44%
# Epoch 114/200 | lr=0.0003 | Train Loss=1.9188, Train Acc=76.45% | Val Loss=1.6813, Val Acc=78.70%
# Epoch 115/200 | lr=0.0003 | Train Loss=1.6854, Train Acc=82.41% | Val Loss=1.7375, Val Acc=76.33%
# Epoch 116/200 | lr=0.0003 | Train Loss=1.7564, Train Acc=81.07% | Val Loss=1.6489, Val Acc=77.51%
# Epoch 117/200 | lr=0.0003 | Train Loss=1.7959, Train Acc=78.63% | Val Loss=1.6585, Val Acc=76.92%
# Epoch 118/200 | lr=0.0003 | Train Loss=1.9771, Train Acc=74.72% | Val Loss=1.6673, Val Acc=76.92%
# Epoch 119/200 | lr=0.0003 | Train Loss=1.8472, Train Acc=78.25% | Val Loss=1.7064, Val Acc=76.04%
# Epoch 120/200 | lr=0.0003 | Train Loss=2.0148, Train Acc=74.10% | Val Loss=1.6500, Val Acc=77.81%
# Epoch 121/200 | lr=0.0003 | Train Loss=1.6727, Train Acc=82.53% | Val Loss=1.7213, Val Acc=74.85%
# Epoch 122/200 | lr=0.0003 | Train Loss=1.7055, Train Acc=81.10% | Val Loss=1.6394, Val Acc=78.40%
# Epoch 123/200 | lr=0.0003 | Train Loss=1.7936, Train Acc=79.78% | Val Loss=1.7157, Val Acc=73.96%
# Epoch 124/200 | lr=0.0003 | Train Loss=1.8001, Train Acc=79.45% | Val Loss=1.6949, Val Acc=76.04%
# Epoch 125/200 | lr=0.0003 | Train Loss=1.7505, Train Acc=80.45% | Val Loss=1.6807, Val Acc=75.74%
# Epoch 126/200 | lr=0.0003 | Train Loss=1.8385, Train Acc=78.42% | Val Loss=1.6948, Val Acc=77.22%
# Epoch 127/200 | lr=0.0003 | Train Loss=1.9962, Train Acc=72.46% | Val Loss=1.6992, Val Acc=76.63%
# Epoch 128/200 | lr=0.0003 | Train Loss=1.8545, Train Acc=75.33% | Val Loss=1.7102, Val Acc=77.51%
# Epoch 129/200 | lr=0.0003 | Train Loss=1.6319, Train Acc=83.82% | Val Loss=1.6523, Val Acc=77.51%
# Epoch 130/200 | lr=0.0003 | Train Loss=1.7885, Train Acc=80.10% | Val Loss=1.6361, Val Acc=79.88%
# ✅ New best model saved: 79.88%
# Epoch 131/200 | lr=0.0003 | Train Loss=1.7365, Train Acc=80.07% | Val Loss=1.6929, Val Acc=76.33%
# Epoch 132/200 | lr=0.0003 | Train Loss=1.8301, Train Acc=77.49% | Val Loss=1.7180, Val Acc=75.74%
# Epoch 133/200 | lr=0.0003 | Train Loss=1.8674, Train Acc=77.07% | Val Loss=1.6992, Val Acc=76.92%
# Epoch 134/200 | lr=0.0003 | Train Loss=1.6696, Train Acc=81.46% | Val Loss=1.7020, Val Acc=75.74%
# Epoch 135/200 | lr=0.0003 | Train Loss=1.8317, Train Acc=78.52% | Val Loss=1.6697, Val Acc=75.15%
# Epoch 136/200 | lr=0.0003 | Train Loss=1.8543, Train Acc=78.53% | Val Loss=1.6476, Val Acc=76.33%
# Epoch 137/200 | lr=0.0003 | Train Loss=1.8330, Train Acc=77.47% | Val Loss=1.7109, Val Acc=74.56%
# Epoch 138/200 | lr=0.0003 | Train Loss=1.8186, Train Acc=79.40% | Val Loss=1.6970, Val Acc=74.26%
# Epoch 139/200 | lr=0.0003 | Train Loss=1.8968, Train Acc=77.69% | Val Loss=1.7374, Val Acc=74.56%
# Epoch 140/200 | lr=0.0003 | Train Loss=1.5875, Train Acc=83.86% | Val Loss=1.6265, Val Acc=77.81%
# Epoch 141/200 | lr=0.0003 | Train Loss=1.9259, Train Acc=76.11% | Val Loss=1.7202, Val Acc=74.56%
# Epoch 142/200 | lr=0.0003 | Train Loss=1.6558, Train Acc=82.72% | Val Loss=1.6781, Val Acc=77.51%
# Epoch 143/200 | lr=0.0003 | Train Loss=1.6954, Train Acc=81.00% | Val Loss=1.7765, Val Acc=75.74%
# Epoch 144/200 | lr=0.0003 | Train Loss=1.6735, Train Acc=81.71% | Val Loss=1.6805, Val Acc=76.33%
# Epoch 145/200 | lr=0.0003 | Train Loss=1.8915, Train Acc=76.53% | Val Loss=1.6961, Val Acc=76.33%
# Epoch 146/200 | lr=0.0003 | Train Loss=1.5563, Train Acc=84.91% | Val Loss=1.6507, Val Acc=77.51%
# Epoch 147/200 | lr=0.0003 | Train Loss=1.7372, Train Acc=81.57% | Val Loss=1.6599, Val Acc=76.92%
# Epoch 148/200 | lr=0.0003 | Train Loss=1.8027, Train Acc=79.72% | Val Loss=1.6471, Val Acc=79.59%
# Epoch 149/200 | lr=0.0003 | Train Loss=1.6579, Train Acc=83.83% | Val Loss=1.6842, Val Acc=76.92%
# Epoch 150/200 | lr=0.0003 | Train Loss=1.7821, Train Acc=80.06% | Val Loss=1.6435, Val Acc=77.51%
# Epoch 151/200 | lr=0.0003 | Train Loss=1.8083, Train Acc=78.47% | Val Loss=1.6644, Val Acc=76.33%
# Epoch 152/200 | lr=0.0003 | Train Loss=1.8440, Train Acc=77.17% | Val Loss=1.6605, Val Acc=77.81%
# Epoch 153/200 | lr=0.0003 | Train Loss=1.7579, Train Acc=81.05% | Val Loss=1.6951, Val Acc=76.63%
# Epoch 154/200 | lr=0.0003 | Train Loss=1.8264, Train Acc=78.91% | Val Loss=1.7244, Val Acc=74.56%
# Epoch 155/200 | lr=0.0003 | Train Loss=1.8806, Train Acc=77.74% | Val Loss=1.6505, Val Acc=76.92%
# Epoch 156/200 | lr=0.0003 | Train Loss=1.8276, Train Acc=77.31% | Val Loss=1.6787, Val Acc=76.63%
# Epoch 157/200 | lr=0.0003 | Train Loss=1.9207, Train Acc=75.02% | Val Loss=1.6565, Val Acc=76.33%
# Epoch 158/200 | lr=0.0003 | Train Loss=1.6798, Train Acc=81.41% | Val Loss=1.6633, Val Acc=75.15%
# Epoch 159/200 | lr=0.0003 | Train Loss=1.8161, Train Acc=78.08% | Val Loss=1.6308, Val Acc=78.40%
# Epoch 160/200 | lr=0.0003 | Train Loss=2.0430, Train Acc=73.10% | Val Loss=1.6635, Val Acc=77.51%
# Epoch 161/200 | lr=0.0003 | Train Loss=1.7887, Train Acc=78.63% | Val Loss=1.6713, Val Acc=76.04%
# Epoch 162/200 | lr=0.0003 | Train Loss=1.6993, Train Acc=81.46% | Val Loss=1.7110, Val Acc=76.04%
# Epoch 163/200 | lr=0.0003 | Train Loss=1.9272, Train Acc=76.33% | Val Loss=1.7332, Val Acc=73.67%
# Epoch 164/200 | lr=0.0003 | Train Loss=1.7642, Train Acc=78.10% | Val Loss=1.6715, Val Acc=74.85%
# Epoch 165/200 | lr=0.0003 | Train Loss=1.7897, Train Acc=78.96% | Val Loss=1.6618, Val Acc=77.81%
# Epoch 166/200 | lr=0.0003 | Train Loss=1.8465, Train Acc=77.37% | Val Loss=1.7149, Val Acc=77.22%
# Epoch 167/200 | lr=0.0003 | Train Loss=1.6581, Train Acc=82.09% | Val Loss=1.7060, Val Acc=77.51%
# Epoch 168/200 | lr=0.0003 | Train Loss=1.8114, Train Acc=78.62% | Val Loss=1.6768, Val Acc=76.33%
# Epoch 169/200 | lr=0.0003 | Train Loss=1.6847, Train Acc=82.55% | Val Loss=1.6664, Val Acc=75.74%
# Epoch 170/200 | lr=0.0003 | Train Loss=1.7365, Train Acc=80.31% | Val Loss=1.7011, Val Acc=77.22%
# Epoch 171/200 | lr=0.0003 | Train Loss=1.8253, Train Acc=77.93% | Val Loss=1.7235, Val Acc=73.96%
# Epoch 172/200 | lr=0.0003 | Train Loss=1.8436, Train Acc=77.07% | Val Loss=1.6692, Val Acc=77.51%
# Epoch 173/200 | lr=0.0003 | Train Loss=1.7643, Train Acc=80.33% | Val Loss=1.6862, Val Acc=76.92%
# Epoch 174/200 | lr=0.0003 | Train Loss=1.6523, Train Acc=82.71% | Val Loss=1.7150, Val Acc=73.96%
# Epoch 175/200 | lr=0.0003 | Train Loss=1.6755, Train Acc=81.54% | Val Loss=1.7063, Val Acc=74.26%
# Epoch 176/200 | lr=0.0003 | Train Loss=1.6850, Train Acc=80.75% | Val Loss=1.6912, Val Acc=76.63%
# Epoch 177/200 | lr=0.0003 | Train Loss=1.7643, Train Acc=81.49% | Val Loss=1.6683, Val Acc=76.63%
# Epoch 178/200 | lr=0.0003 | Train Loss=1.7640, Train Acc=78.93% | Val Loss=1.7561, Val Acc=74.26%
# Epoch 179/200 | lr=0.0003 | Train Loss=1.8400, Train Acc=76.87% | Val Loss=1.6887, Val Acc=75.74%
# Epoch 180/200 | lr=0.0003 | Train Loss=1.7521, Train Acc=80.96% | Val Loss=1.7381, Val Acc=74.85%
# Epoch 181/200 | lr=0.0003 | Train Loss=1.8124, Train Acc=78.85% | Val Loss=1.6657, Val Acc=76.63%
# Epoch 182/200 | lr=0.0003 | Train Loss=1.8240, Train Acc=76.27% | Val Loss=1.6428, Val Acc=77.22%
# Epoch 183/200 | lr=0.0003 | Train Loss=1.7577, Train Acc=79.41% | Val Loss=1.6695, Val Acc=78.11%
# Epoch 184/200 | lr=0.0003 | Train Loss=1.6627, Train Acc=82.28% | Val Loss=1.6964, Val Acc=78.40%
# Epoch 185/200 | lr=0.0003 | Train Loss=1.7421, Train Acc=80.50% | Val Loss=1.6626, Val Acc=78.70%
# Epoch 186/200 | lr=0.0003 | Train Loss=1.8082, Train Acc=78.44% | Val Loss=1.6571, Val Acc=79.59%
# Epoch 187/200 | lr=0.0003 | Train Loss=1.6824, Train Acc=83.21% | Val Loss=1.7361, Val Acc=76.04%
# Epoch 188/200 | lr=0.0003 | Train Loss=1.7036, Train Acc=81.28% | Val Loss=1.6872, Val Acc=78.40%
# Epoch 189/200 | lr=0.0003 | Train Loss=1.5715, Train Acc=84.25% | Val Loss=1.6794, Val Acc=77.81%
# Epoch 190/200 | lr=0.0003 | Train Loss=1.9426, Train Acc=74.77% | Val Loss=1.6731, Val Acc=78.11%
# Epoch 191/200 | lr=0.0003 | Train Loss=1.8405, Train Acc=78.84% | Val Loss=1.7065, Val Acc=75.74%
# Epoch 192/200 | lr=0.0003 | Train Loss=1.7470, Train Acc=80.59% | Val Loss=1.6866, Val Acc=77.51%
# Epoch 193/200 | lr=0.0003 | Train Loss=1.7839, Train Acc=78.25% | Val Loss=1.6693, Val Acc=77.51%
# Epoch 194/200 | lr=0.0003 | Train Loss=1.7134, Train Acc=81.51% | Val Loss=1.6598, Val Acc=80.18%
# ✅ New best model saved: 80.18%
# Epoch 195/200 | lr=0.0003 | Train Loss=1.6685, Train Acc=82.10% | Val Loss=1.6847, Val Acc=78.11%
# Epoch 196/200 | lr=0.0003 | Train Loss=1.7149, Train Acc=79.64% | Val Loss=1.6942, Val Acc=76.92%
# Epoch 197/200 | lr=0.0003 | Train Loss=1.7167, Train Acc=81.01% | Val Loss=1.6790, Val Acc=77.22%
# Epoch 198/200 | lr=0.0003 | Train Loss=1.7361, Train Acc=80.22% | Val Loss=1.6550, Val Acc=77.81%
# Epoch 199/200 | lr=0.0003 | Train Loss=1.5334, Train Acc=84.80% | Val Loss=1.6553, Val Acc=77.22%
# Epoch 200/200 | lr=0.0003 | Train Loss=1.5664, Train Acc=84.94% | Val Loss=1.7101, Val Acc=76.63%
#
# ✨ Training finished!

# %%
import matplotlib.pyplot as plt

print("\n--- Plotting Training History with Bold Colors ---")
fig, (ax1, ax2) = plt.subplots(2, 1, figsize=(12, 10))

# Loss plot
ax1.plot(train_loss_history, label='Train Loss', color='#1f77b4', linewidth=2.5)  # Deep blue
ax1.plot(val_loss_history, label='Validation Loss', color='#ff7f0e', linewidth=2.5)  # Orange
ax1.set_title('Model Loss Over Epochs', fontsize=16, fontweight='bold')
ax1.set_xlabel('Epochs', fontsize=14)
ax1.set_ylabel('Loss', fontsize=14)
ax1.legend(fontsize=12)
ax1.grid(True, linestyle='--', alpha=0.7)

# Accuracy plot
ax2.plot(train_acc_history, label='Train Accuracy', color='#2ca02c', linewidth=2.5)  # Green
ax2.plot(val_acc_history, label='Validation Accuracy', color='#d62728', linewidth=2.5)  # Red
ax2.set_title('Model Accuracy Over Epochs', fontsize=16, fontweight='bold')
ax2.set_xlabel('Epochs', fontsize=14)
ax2.set_ylabel('Accuracy (%)', fontsize=14)
ax2.legend(fontsize=12)
ax2.grid(True, linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()
# Out:
# --- Plotting Training History with Bold Colors ---

# %%
# Paths (update with your actual files)
LANDMARK_PATH = "/kaggle/input/landmarks-553-for-300-classes/Landmarks_300_553_3D.npz"   # your big NPZ with 300 classes
SPLIT_FILE_PATH = "/kaggle/input/wlasl2000-resized/wlasl-complete/nslt_100.json" # JSON split file

# Create test dataset
test_dataset = WLASLLandmarkDataset(
    landmark_path=LANDMARK_PATH,
    split_file_path=SPLIT_FILE_PATH,
    split='test'
)
# Out:
# ✅ Created 'test' split with 258 samples.

# %%
from torch.utils.data import DataLoader

test_loader = DataLoader(
    test_dataset,
    batch_size=32,   # adjust depending on GPU memory
    shuffle=False,
    collate_fn=variable_length_collate_fn,
    num_workers=2,   # increase if running locally, set 0 for Kaggle
    pin_memory=True
)

# %%
# Input size = 553 landmarks × 3 coords (x,y,z)
INPUT_SIZE = 553 * 3
HIDDEN_SIZE = 256
NUM_LAYERS = 2
DROPOUT_RATE = 0.3
NUM_CLASSES = 100

model = LandmarkBiLSTMAttentionModel(
    input_size=INPUT_SIZE,
    num_classes=NUM_CLASSES,
    hidden_size=HIDDEN_SIZE,
    num_layers=NUM_LAYERS,
    dropout_rate=DROPOUT_RATE
).to(DEVICE)

model.load_state_dict(torch.load("/kaggle/working/best_landmark_attention_model_100.pth", map_location=DEVICE))
model.eval()
# Out:
# LandmarkBiLSTMAttentionModel(
#   (lstm): LSTM(1659, 256, num_layers=2, batch_first=True, dropout=0.2, bidirectional=True)
#   (attention): Attention(
#     (attn_net): Sequential(
#       (0): Linear(in_features=512, out_features=256, bias=True)
#       (1): Tanh()
#       (2): Linear(in_features=256, out_features=1, bias=True)
#     )
#   )
#   (layer_norm): LayerNorm((512,), eps=1e-05, elementwise_affine=True)
#   (dropout): Dropout(p=0.3, inplace=False)
#   (fc): Linear(in_features=512, out_features=100, bias=True)
# )

# %%
import torch.nn.functional as F

test_loss, test_correct, test_total = 0.0, 0, 0
criterion = nn.CrossEntropyLoss()

with torch.no_grad():
    for landmarks, labels, lengths in test_loader:
        landmarks, labels, lengths = landmarks.to(DEVICE), labels.to(DEVICE), lengths.to(DEVICE)
        outputs = model(landmarks, lengths)
        loss = criterion(outputs, labels)

        test_loss += loss.item() * labels.size(0)
        _, predicted = torch.max(outputs, 1)
        test_total += labels.size(0)
        test_correct += (predicted == labels).sum().item()

avg_test_loss = test_loss / max(1, test_total)
test_accuracy = 100.0 * test_correct / max(1, test_total)

print(f"\n📊 Test Loss={avg_test_loss:.4f}, Test Accuracy={test_accuracy:.2f}%")
# Out:
# 📊 Test Loss=1.1205, Test Accuracy=77.13%
